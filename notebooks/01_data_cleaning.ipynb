# %% [markdown]
# # IPL Cricket Performance Analysis (2008–2024)
# ## Notebook 01 — Data Cleaning
#
# **Author:** Portfolio Project
# **Dataset:** Kaggle IPL Complete Dataset (matches.csv + deliveries.csv)
# **Goal:** Produce clean, feature-enriched datasets ready for EDA and modelling.
#
# ---

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'src'))
from data_cleaning import run_cleaning_pipeline

matches, deliveries = run_cleaning_pipeline()

# %% [markdown]
# ## Matches — first look

# %%
matches.head()

# %%
matches.info()

# %%
matches.describe(include='all').T

# %% [markdown]
# ## Deliveries — first look

# %%
deliveries.head()

# %%
deliveries.info()

# %% [markdown]
# ## Null audit post-cleaning

# %%
import pandas as pd
null_m = matches.isnull().sum()
null_d = deliveries.isnull().sum()
print('Matches nulls:\n', null_m[null_m > 0])
print('\nDeliveries nulls:\n', null_d[null_d > 0])

# %% [markdown]
# ## Season distribution

# %%
matches.groupby('season').size().rename('matches_played')
